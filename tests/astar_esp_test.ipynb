# %%
# %load_ext autoreload
# %autoreload 2

from astar_eps import astar_eps
import networkx as nx
import heapq
import numpy as np
import pickle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
file = open("paris_graph_with_weights.pickle", "rb")
graphParis = pickle.load(file)
algo = astar_eps(graphParis, 4)
# %matplotlib inline

# %%
#resultastar = algo.a_star(graphParis,135578024, 2160034030)
resultastar = algo.a_star(graphParis,135578024, 9429648010,1000, 0.1)
#resultastar = algo.a_star(graphParis,135578024, 17348293)
#resultastar = algo.a_star(graphParis,135578024, 277591245)
print(resultastar)
# Out:
# 0 noeuds explorés, 0 noeuds restants dans la file
# 400 noeuds explorés, 129 noeuds restants dans la file
# 600 noeuds explorés, 155 noeuds restants dans la file
# 1100 noeuds explorés, 213 noeuds restants dans la file
# 1300 noeuds explorés, 245 noeuds restants dans la file
# 1800 noeuds explorés, 306 noeuds restants dans la file
# 2000 noeuds explorés, 331 noeuds restants dans la file
# 2100 noeuds explorés, 339 noeuds restants dans la file
# 3300 noeuds explorés, 450 noeuds restants dans la file
# 3800 noeuds explorés, 510 noeuds restants dans la file
# 4200 noeuds explorés, 562 noeuds restants dans la file
# 4500 noeuds explorés, 596 noeuds restants dans la file
# 4600 noeuds explorés, 605 noeuds restants dans la file
# 4700 noeuds explorés, 611 noeuds restants dans la file
# 4800 noeuds explorés, 627 noeuds restants dans la file
# 5100 noeuds explorés, 659 noeuds restants dans la file
# 5200 noeuds explorés, 676 noeuds restants dans la file
# 5400 noeuds explorés, 704 noeuds restants dans la file
# 5600 noeuds explorés, 729 noeuds restants dans la file
# 5700 noeuds explorés, 737 noeuds restants dans la file
# 6000 noeuds explorés, 760 noeuds restants dans la file
# 6200 noeuds explorés, 777 noeuds restants dans la file
# 6400 noeuds explorés, 796 noeuds restants dans la file
# 6800 noeuds explorés, 814 noeuds restants dans la file
# 6900 noeuds explorés, 825 noeuds restants dans la file
# 7000 noeuds explorés, 824 noeuds restants dans la file
# 7200 noeuds explorés, 843 noeuds restants dans la file
# 7800 noeuds explorés, 912 noeuds restants dans la file
# 7900 noeuds explorés, 922 noeuds restants dans la file
# 8400 noeuds explorés, 962 noeuds restants dans la file
# 8600 noeuds explorés, 990 noeuds restants dans la file
# 9000 noeuds explorés, 1008 noeuds restants dans la file
# 9300 noeuds explorés, 1034 noeuds restants dans la file
# 9500 noeuds explorés, 1047 noeuds restants dans la file
# 10200 noeuds explorés, 1094 noeuds restants dans la file
# 10500 noeuds explorés, 1128 noeuds restants dans la file
# 10800 noeuds explorés, 1138 noeuds restants dans la file
# 10900 noeuds explorés, 1136 noeuds restants dans la file
# 11200 noeuds explorés, 1153 noeuds restants dans la file
# 11400 noeuds explorés, 1169 noeuds restants dans la file
# 11500 noeuds explorés, 1172 noeuds restants dans la file
# 11700 noeuds explorés, 1192 noeuds restants dans la file
# 12300 noeuds explorés, 1218 noeuds restants dans la file
# 13000 noeuds explorés, 1263 noeuds restants dans la file
# 13500 noeuds explorés, 1318 noeuds restants dans la file
# 13700 noeuds explorés, 1351 noeuds restants dans la file
# 14000 noeuds explorés, 1402 noeuds restants dans la file
# 14100 noeuds explorés, 1421 noeuds restants dans la file
# 14900 noeuds explorés, 1500 noeuds restants dans la file
# 15000 noeuds explorés, 1505 noeuds restants dans la file
# 15100 noeuds explorés, 1508 noeuds restants dans la file
# 15700 noeuds explorés, 1561 noeuds restants dans la file
# 16200 noeuds explorés, 1584 noeuds restants dans la file
# 16400 noeuds explorés, 1588 noeuds restants dans la file
# 16500 noeuds explorés, 1588 noeuds restants dans la file
# 16900 noeuds explorés, 1590 noeuds restants dans la file
# 17000 noeuds explorés, 1594 noeuds restants dans la file
# 17100 noeuds explorés, 1602 noeuds restants dans la file
# 17500 noeuds explorés, 1613 noeuds restants dans la file
# 17700 noeuds explorés, 1622 noeuds restants dans la file
# 17900 noeuds explorés, 1642 noeuds restants dans la file
# 18000 noeuds explorés, 1657 noeuds restants dans la file
# 18400 noeuds explorés, 1686 noeuds restants dans la file
# 18500 noeuds explorés, 1689 noeuds restants dans la file
# 18800 noeuds explorés, 1715 noeuds restants dans la file
# 19600 noeuds explorés, 1756 noeuds restants dans la file
# 20500 noeuds explorés, 1808 noeuds restants dans la file
# 20700 noeuds explorés, 1817 noeuds restants dans la file
# 20800 noeuds explorés, 1812 noeuds restants dans la file
# 21200 noeuds explorés, 1836 noeuds restants dans la file
# 21300 noeuds explorés, 1833 noeuds restants dans la file
# 21500 noeuds explorés, 1845 noeuds restants dans la file
# 21700 noeuds explorés, 1850 noeuds restants dans la file
# 22100 noeuds explorés, 1888 noeuds restants dans la file
# 22300 noeuds explorés, 1901 noeuds restants dans la file
# 23300 noeuds explorés, 1963 noeuds restants dans la file
# 23400 noeuds explorés, 1965 noeuds restants dans la file
# 23700 noeuds explorés, 1983 noeuds restants dans la file
# 23800 noeuds explorés, 1994 noeuds restants dans la file
# 24100 noeuds explorés, 2011 noeuds restants dans la file
# 24500 noeuds explorés, 2044 noeuds restants dans la file
# 25000 noeuds explorés, 2089 noeuds restants dans la file
# 25100 noeuds explorés, 2089 noeuds restants dans la file
# 26500 noeuds explorés, 2196 noeuds restants dans la file
# 26800 noeuds explorés, 2226 noeuds restants dans la file
# 26900 noeuds explorés, 2226 noeuds restants dans la file
# 27100 noeuds explorés, 2242 noeuds restants dans la file
# 27300 noeuds explorés, 2249 noeuds restants dans la file
# 27800 noeuds explorés, 2289 noeuds restants dans la file
# 28300 noeuds explorés, 2314 noeuds restants dans la file
# 28500 noeuds explorés, 2330 noeuds restants dans la file
# 29100 noeuds explorés, 2362 noeuds restants dans la file
# 29400 noeuds explorés, 2375 noeuds restants dans la file
# 29500 noeuds explorés, 2377 noeuds restants dans la file
# 29800 noeuds explorés, 2391 noeuds restants dans la file
# 30400 noeuds explorés, 2426 noeuds restants dans la file
# 30500 noeuds explorés, 2430 noeuds restants dans la file
# 31100 noeuds explorés, 2464 noeuds restants dans la file
# 31300 noeuds explorés, 2486 noeuds restants dans la file
# 31800 noeuds explorés, 2532 noeuds restants dans la file
# 32200 noeuds explorés, 2547 noeuds restants dans la file
# 32300 noeuds explorés, 2555 noeuds restants dans la file
# 32700 noeuds explorés, 2592 noeuds restants dans la file
# 32900 noeuds explorés, 2597 noeuds restants dans la file
# 33100 noeuds explorés, 2602 noeuds restants dans la file
# 33400 noeuds explorés, 2611 noeuds restants dans la file
# 33600 noeuds explorés, 2620 noeuds restants dans la file
# 34100 noeuds explorés, 2641 noeuds restants dans la file
# 34200 noeuds explorés, 2640 noeuds restants dans la file
# 34500 noeuds explorés, 2655 noeuds restants dans la file
# 34600 noeuds explorés, 2659 noeuds restants dans la file
# 35600 noeuds explorés, 2681 noeuds restants dans la file
# 35900 noeuds explorés, 2697 noeuds restants dans la file
# 36000 noeuds explorés, 2701 noeuds restants dans la file
# 36100 noeuds explorés, 2708 noeuds restants dans la file
# 36400 noeuds explorés, 2716 noeuds restants dans la file
# 36500 noeuds explorés, 2719 noeuds restants dans la file
# 37200 noeuds explorés, 2773 noeuds restants dans la file
# 37300 noeuds explorés, 2784 noeuds restants dans la file
# 37700 noeuds explorés, 2809 noeuds restants dans la file
# 38000 noeuds explorés, 2841 noeuds restants dans la file
# 38200 noeuds explorés, 2852 noeuds restants dans la file
# 38300 noeuds explorés, 2850 noeuds restants dans la file
# 38400 noeuds explorés, 2853 noeuds restants dans la file
# 38500 noeuds explorés, 2865 noeuds restants dans la file
# 39200 noeuds explorés, 2910 noeuds restants dans la file
# 39500 noeuds explorés, 2941 noeuds restants dans la file
# 39700 noeuds explorés, 2963 noeuds restants dans la file
# 40000 noeuds explorés, 2996 noeuds restants dans la file
# 40800 noeuds explorés, 3056 noeuds restants dans la file
# 41100 noeuds explorés, 3083 noeuds restants dans la file
# 41600 noeuds explorés, 3119 noeuds restants dans la file
# 41700 noeuds explorés, 3126 noeuds restants dans la file
# 42100 noeuds explorés, 3142 noeuds restants dans la file
# 42200 noeuds explorés, 3154 noeuds restants dans la file
# 42800 noeuds explorés, 3194 noeuds restants dans la file
# 43000 noeuds explorés, 3212 noeuds restants dans la file
# 44000 noeuds explorés, 3262 noeuds restants dans la file
# 44500 noeuds explorés, 3281 noeuds restants dans la file
# 44700 noeuds explorés, 3292 noeuds restants dans la file
# 45000 noeuds explorés, 3328 noeuds restants dans la file
# 45300 noeuds explorés, 3342 noeuds restants dans la file
# 45500 noeuds explorés, 3344 noeuds restants dans la file
# 45600 noeuds explorés, 3346 noeuds restants dans la file
# 45800 noeuds explorés, 3359 noeuds restants dans la file
# 46100 noeuds explorés, 3383 noeuds restants dans la file
# 46500 noeuds explorés, 3435 noeuds restants dans la file
# 46600 noeuds explorés, 3439 noeuds restants dans la file
# 47100 noeuds explorés, 3482 noeuds restants dans la file
# 47400 noeuds explorés, 3520 noeuds restants dans la file
# 48500 noeuds explorés, 3588 noeuds restants dans la file
# 49400 noeuds explorés, 3669 noeuds restants dans la file
# 49700 noeuds explorés, 3669 noeuds restants dans la file
# 49900 noeuds explorés, 3683 noeuds restants dans la file
# 50600 noeuds explorés, 3759 noeuds restants dans la file
# 50800 noeuds explorés, 3765 noeuds restants dans la file
# 52100 noeuds explorés, 3818 noeuds restants dans la file
# 52200 noeuds explorés, 3826 noeuds restants dans la file
# 52300 noeuds explorés, 3833 noeuds restants dans la file
# 52600 noeuds explorés, 3844 noeuds restants dans la file
# 52900 noeuds explorés, 3879 noeuds restants dans la file
# 53500 noeuds explorés, 3919 noeuds restants dans la file
# 53600 noeuds explorés, 3925 noeuds restants dans la file
# 54000 noeuds explorés, 3947 noeuds restants dans la file
# 54100 noeuds explorés, 3951 noeuds restants dans la file
# 54200 noeuds explorés, 3952 noeuds restants dans la file
# 54500 noeuds explorés, 3983 noeuds restants dans la file
# 54800 noeuds explorés, 3999 noeuds restants dans la file
# 54900 noeuds explorés, 4002 noeuds restants dans la file
# 55000 noeuds explorés, 4001 noeuds restants dans la file
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# NOEUD TERMINAL TROUVE
# ...
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5092153449: rec.array([(array([ 90.,  87.,  73., -inf]), 5760792406, 5092153449, 51426, 51479)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 6150074438: rec.array([(array([ 90.,  86.,  73., -inf]), 5760792406, 6150074438, 51426, 51480)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 94158854: rec.array([(array([ 85.,  85.,  68., -inf]), 94158855, 94158854, 45681, 52208)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 256619171: rec.array([(array([ 85.,  85.,  68., -inf]), 94158855, 256619171, 45681, 52210)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 94110200: rec.array([(array([83., 80., 68., 24.]), 3978232561, 94110200, 51822, 52939),
#            (array([ 83.,  79.,  69., -inf]),   94110199, 94110200, 45028, 54639)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 17809179: rec.array([(array([2821.762, 2122.295,  840.545,   10.077]), 94110200, 17809179, 48622, 48695),
#            (array([83., 80., 68., 24.]), 94110200, 17809179, 52939, 53018)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5749702266: rec.array([(array([ 87.,  87.,  73., -inf]), 5142601756, 5749702266, 35933, 50621)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401006: rec.array([(array([ 89.,  89.,  79., -inf]), 26401030, 26401006, 32919, 49201),
#            (array([ 90.,  89.,  78., -inf]), 26401030, 26401006, 34977, 52570)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 559642338: rec.array([(array([ 79.,  74.,  64., -inf]), 94185770, 559642338, 16164, 52979)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 94159197: rec.array([(array([ 86.,  85.,  68., -inf]), 94158854, 94159197, 52208, 53134)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25031316: rec.array([(array([ 91.,  91.,  74., -inf]), 235806764, 25031316, 44424, 52891)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 676821315: rec.array([(array([ 89.,  89.,  73., -inf]), 676821316, 676821315, 15931, 50230),
#            (array([ 90.,  90.,  72., -inf]), 676821316, 676821315, 17035, 52908)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401081: rec.array([(array([ 89.,  86.,  73., -inf]), 26401083, 26401081, 42254, 53281)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26400957: rec.array([(array([ 90.,  86.,  73., -inf]), 26401086, 26400957, 53283, 53685)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 260800258: rec.array([(array([ 82.,  79.,  71., -inf]), 260800266, 260800258, 48314, 52762)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 382068: rec.array([(array([ 91.,  91.,  77., -inf]), 382082, 382068, 47216, 55101)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25095600: rec.array([(array([ 90.,  90.,  73., -inf]), 2418577626, 25095600, 50840, 54331)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 2258592544: rec.array([(array([ 74.,  73.,  71., -inf]), 331432688, 2258592544, 38333, 54488)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5922426587: rec.array([(array([ 75.,  71.,  69., -inf]), 331432688, 5922426587, 38333, 54489)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 2250943366: rec.array([(array([ 87.,  86.,  75., -inf]), 9844189696, 2250943366, 51569, 51578)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 9844189695: rec.array([(array([ 87.,  86.,  75., -inf]), 9688723398, 9844189695, 23749, 51844)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 361086: rec.array([(array([ 87.,  86.,  75., -inf]),  9844189696, 361086, 51569, 51577),
#            (array([ 87.,  87.,  73., -inf]), 10281984728, 361086, 42041, 54421)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 256587669: rec.array([(array([ 87.,  86.,  76., -inf]), 2250943366, 256587669, 51578, 54546)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 9844189696: rec.array([(array([ 87.,  86.,  75., -inf]), 2250943366, 9844189696, 51578, 54548)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 9688784929: rec.array([(array([ 87.,  86.,  75., -inf]), 9844189696, 9688784929, 54548, 54554)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 94157756: rec.array([(array([ 84.,  84.,  68., -inf]), 94157754, 94157756, 40878, 55197)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 256619227: rec.array([(array([ 85.,  84.,  69., -inf]), 94157754, 256619227, 40878, 55198)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 704819766: rec.array([(array([ 90.,  86.,  73., -inf]), 6150074438, 704819766, 51480, 54973)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5760792405: rec.array([(array([ 90.,  87.,  73., -inf]), 6150074438, 5760792405, 51480, 54974)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401669: rec.array([(array([ 90.,  86.,  73., -inf]), 704819766, 26401669, 54973, 55086)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 704819959: rec.array([(array([90., 87., 73., 44.]), 704819766, 704819959, 54973, 55087)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401666: rec.array([(array([ 90.,  86.,  73., -inf]), 26401669, 26401666, 55086, 55188)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401695: rec.array([(array([ 90.,  87.,  74., -inf]), 26401669, 26401695, 55086, 55190)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401664: rec.array([(array([ 90.,  86.,  75., -inf]), 26401666, 26401664, 53782, 53936),
#            (array([90., 86., 73., 27.]), 26401666, 26401664, 53827, 53998)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401689: rec.array([(array([ 90.,  86.,  75., -inf]), 26401666, 26401689, 53782, 53938),
#            (array([90., 86., 73., 27.]), 26401666, 26401689, 53827, 54000)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 361060: rec.array([(array([ 92.,  92.,  75., -inf]), 25034403, 361060, 55261, 55263)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401688: rec.array([(array([ 90.,  86.,  75., -inf]), 26401689, 26401688, 53938, 54187),
#            (array([90., 86., 73., 27.]), 26401689, 26401688, 54000, 54234)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401690: rec.array([(array([ 90.,  86.,  75., -inf]), 26401689, 26401690, 53938, 54189),
#            (array([90., 86., 73., 27.]), 26401689, 26401690, 54000, 54236)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 382069: rec.array([(array([5806.682, 5724.656, 1373.755,    0.   ]), 382068, 382069, 50734, 52620)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401687: rec.array([(array([ 90.,  86.,  75., -inf]), 26401688, 26401687, 54187, 54310),
#            (array([90., 86., 73., 27.]), 26401688, 26401687, 54234, 54352)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 26401691: rec.array([(array([ 91.,  86.,  75., -inf]), 26401688, 26401691, 54187, 54311),
#            (array([91., 86., 73., 27.]), 26401688, 26401691, 54234, 54353)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 208381994: rec.array([(array([ 90.,  86.,  75., -inf]), 26401687, 208381994, 54310, 54332),
#            (array([90., 86., 73., 27.]), 26401687, 208381994, 54352, 54377)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 1969476329: rec.array([(array([ 90.,  86.,  75., -inf]), 26401687, 1969476329, 54310, 54334),
#            (array([90., 86., 73., 27.]), 26401687, 1969476329, 54352, 54379)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 277500566: rec.array([(array([ 90.,  86.,  75., -inf]), 26401687, 277500566, 54310, 54335),
#            (array([90., 86., 73., 27.]), 26401687, 277500566, 54352, 54380)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 256619197: rec.array([(array([3207.773, 3149.821,  933.689,    0.   ]), 256619227, 256619197, 51696, 52714)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 368140: rec.array([(array([ 90.,  86.,  75., -inf]), 277500566, 368140, 54335, 54389),
#            (array([90., 86., 73., 27.]), 277500566, 368140, 54380, 54443)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 277500563: rec.array([(array([ 91.,  86.,  75., -inf]), 277500566, 277500563, 54335, 54390),
#            (array([91., 86., 73., 27.]), 277500566, 277500563, 54380, 54444)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 4520839549: rec.array([(array([ 90.,  86.,  75., -inf]), 277500566, 4520839549, 54335, 54391),
#            (array([90., 86., 73., 27.]), 277500566, 4520839549, 54380, 54445)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 644163: rec.array([(array([ 90.,  86.,  76., -inf]), 368140, 644163, 54389, 54410),
#            (array([90., 86., 73., 27.]), 368140, 644163, 54443, 54449)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 208381519: rec.array([(array([90., 86., 76., 27.]), 368140, 208381519, 52917, 52927),
#            (array([ 90.,  87.,  78., -inf]), 368140, 208381519, 54273, 54288),
#            (array([ 91.,  87.,  76., -inf]), 368140, 208381519, 54389, 54411),
#            (array([91., 86., 73., 27.]), 368140, 208381519, 54443, 54450)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 94143743: rec.array([(array([ 87.,  87.,  77., -inf]), 94145390, 94143743, 38089, 54396),
#            (array([87., 87., 75., 20.]), 94145390, 94143743, 38267, 54598)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25183526: rec.array([(array([5375.697, 5375.697, 1197.482,    0.   ]), 2418577616, 25183526, 47393, 53007)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 277500567: rec.array([(array([ 90.,  86.,  75., -inf]), 1969476329, 277500567, 54334, 54765),
#            (array([90., 86., 73., 27.]), 1969476329, 277500567, 54379, 54808)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25095606: rec.array([(array([5399.202, 5399.202, 1141.587,    0.   ]), 25095608, 25095606, 47394, 53559)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 24912071: rec.array([(array([ 74.,  71.,  62., -inf]), 1662201480, 24912071, 29460, 54452)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 1662201483: rec.array([(array([ 73.,  71.,  62., -inf]), 1662201480, 1662201483, 29460, 54453)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5334674562: rec.array([(array([5679.744, 5597.718, 1531.708,    0.   ]), 259637377, 5334674562, 43139, 54705)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 621240917: rec.array([(array([3020.067, 2320.6  , 1038.85 ,   10.077]), 17809179, 621240917, 48695, 55019),
#            (array([84., 81., 73., 24.]), 17809179, 621240917, 48708, 55034)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 5971534051: rec.array([(array([2964.99 , 2122.295,  840.545,   10.077]), 17809179, 5971534051, 48695, 55021),
#            (array([84., 80., 71., 24.]), 17809179, 5971534051, 48708, 55036)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 382078: rec.array([(array([5744.132, 5662.106, 1466.096,    0.   ]), 382082, 382078, 47216, 55099)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 361059: rec.array([(array([ 92.,  91.,  75., -inf]), 25034403, 361059, 55261, 55262)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25034403: rec.array([(array([ 92.,  92.,  76., -inf]), 25101538, 25034403, 55264, 55265)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 25101538: rec.array([(array([ 92.,  92.,  76., -inf]), 245535448, 25101538, 55267, 55269)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 7049374628: rec.array([(array([ 92.,  92.,  75., -inf]), 245535448, 7049374628, 55267, 55272)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 245535448: rec.array([(array([6266.131, 6113.934, 1327.681,    0.   ]), 25101538, 245535448, 55264, 55267)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 247188062: rec.array([(array([6372.045, 6083.639, 1297.386,    0.   ]), 25101538, 247188062, 55264, 55268)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 9429648010: rec.array([(array([6290.48 , 6138.283, 1352.03 ,    0.   ]), 245535448, 9429648010, 55267, 55270)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')]), 9429648011: rec.array([(array([6298.894, 6146.697, 1360.444,    0.   ]), 245535448, 9429648011, 55267, 55271)],
#           dtype=[('weights', 'O'), ('prevnode', '<i8'), ('node', '<i8'), ('previd', '<i8'), ('id', '<i8')])}
